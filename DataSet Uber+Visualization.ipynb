# %%
import pandas as pd
import numpy as np

# %%
a=pd.read_csv(r"E:\Python Data Science\Documents\uber - uber.csv")

# %% [markdown]
# To print 1st Thousand Rows

# %%
b=a.head(1000)
b
# Out:
#      Unnamed: 0                  key  fare_amount          pickup_datetime  \
# 0      24238194  2015-05-07 19:52:06          7.5  2015-05-07 19:52:06 UTC
# 1      27835199  2009-07-17 20:04:56          7.7  2009-07-17 20:04:56 UTC
# 2      44984355  2009-08-24 21:45:00         12.9  2009-08-24 21:45:00 UTC
# 3      25894730   2009-06-26 8:22:21          5.3  2009-06-26 08:22:21 UTC
# 4      17610152  2014-08-28 17:47:00         16.0  2014-08-28 17:47:00 UTC
# ..          ...                  ...          ...                      ...
# 995    13439193   2011-05-04 6:39:00          5.7  2011-05-04 06:39:00 UTC
# 996    32405310  2011-11-23 20:43:20          8.1  2011-11-23 20:43:20 UTC
# 997    51612001  2010-01-11 20:58:00          8.5  2010-01-11 20:58:00 UTC
# 998      937243  2013-06-12 17:01:24          5.5  2013-06-12 17:01:24 UTC
# 999    47946613  2011-12-11 21:48:22          9.7  2011-12-11 21:48:22 UTC
#
# ...

# %% [markdown]
# To print last 5 rows

# %%
a.tail()
# Out:
#         Unnamed: 0                  key  fare_amount          pickup_datetime  \
# 199995    42598914  2012-10-28 10:49:00          3.0  2012-10-28 10:49:00 UTC
# 199996    16382965   2014-03-14 1:09:00          7.5  2014-03-14 01:09:00 UTC
# 199997    27804658   2009-06-29 0:42:00         30.9  2009-06-29 00:42:00 UTC
# 199998    20259894  2015-05-20 14:56:25         14.5  2015-05-20 14:56:25 UTC
# 199999    11951496   2010-05-15 4:08:00         14.1  2010-05-15 04:08:00 UTC
#
#         pickup_longitude  pickup_latitude  dropoff_longitude  \
# 199995        -73.987042        40.739367         -73.986525
# 199996        -73.984722        40.736837         -74.006672
# 199997        -73.986017        40.756487         -73.858957
# 199998        -73.997124        40.725452         -73.983215
# 199999        -73.984395        40.720077         -73.985508
#
#         dropoff_latitude  passenger_count
# 199995         40.740297                1
# 199996         40.739620                1
# ...

# %% [markdown]
# To find shape

# %%
a.shape
# Out:
# (200000, 9)

# %% [markdown]
# To find size

# %%
a.size
# Out:
# 1800000

# %% [markdown]
# To describe

# %%
a.describe()
# Out:
#          Unnamed: 0    fare_amount  pickup_longitude  pickup_latitude  \
# count  2.000000e+05  200000.000000     200000.000000    200000.000000
# mean   2.771250e+07      11.359955        -72.527638        39.935885
# std    1.601382e+07       9.901776         11.437787         7.720539
# min    1.000000e+00     -52.000000      -1340.648410       -74.015515
# 25%    1.382535e+07       6.000000        -73.992065        40.734796
# 50%    2.774550e+07       8.500000        -73.981823        40.752592
# 75%    4.155530e+07      12.500000        -73.967153        40.767158
# max    5.542357e+07     499.000000         57.418457      1644.421482
#
#        dropoff_longitude  dropoff_latitude  passenger_count
# count      199999.000000     199999.000000    200000.000000
# mean          -72.525292         39.923890         1.684535
# std            13.117408          6.794829         1.385997
# min         -3356.666300       -881.985513         0.000000
# ...

# %% [markdown]
# To check the null values

# %%
a.isna()
# Out:
#         Unnamed: 0    key  fare_amount  pickup_datetime  pickup_longitude  \
# 0            False  False        False            False             False
# 1            False  False        False            False             False
# 2            False  False        False            False             False
# 3            False  False        False            False             False
# 4            False  False        False            False             False
# ...            ...    ...          ...              ...               ...
# 199995       False  False        False            False             False
# 199996       False  False        False            False             False
# 199997       False  False        False            False             False
# 199998       False  False        False            False             False
# 199999       False  False        False            False             False
#
#         pickup_latitude  dropoff_longitude  dropoff_latitude  passenger_count
# ...

# %% [markdown]
# To fill the null value

# %%
a.fillna(value=4)
# Out:
#         Unnamed: 0                  key  fare_amount          pickup_datetime  \
# 0         24238194  2015-05-07 19:52:06          7.5  2015-05-07 19:52:06 UTC
# 1         27835199  2009-07-17 20:04:56          7.7  2009-07-17 20:04:56 UTC
# 2         44984355  2009-08-24 21:45:00         12.9  2009-08-24 21:45:00 UTC
# 3         25894730   2009-06-26 8:22:21          5.3  2009-06-26 08:22:21 UTC
# 4         17610152  2014-08-28 17:47:00         16.0  2014-08-28 17:47:00 UTC
# ...            ...                  ...          ...                      ...
# 199995    42598914  2012-10-28 10:49:00          3.0  2012-10-28 10:49:00 UTC
# 199996    16382965   2014-03-14 1:09:00          7.5  2014-03-14 01:09:00 UTC
# 199997    27804658   2009-06-29 0:42:00         30.9  2009-06-29 00:42:00 UTC
# 199998    20259894  2015-05-20 14:56:25         14.5  2015-05-20 14:56:25 UTC
# 199999    11951496   2010-05-15 4:08:00         14.1  2010-05-15 04:08:00 UTC
#
# ...

# %% [markdown]
# To drop the null valued rows

# %%
a.dropna()
# Out:
#         Unnamed: 0                  key  fare_amount          pickup_datetime  \
# 0         24238194  2015-05-07 19:52:06          7.5  2015-05-07 19:52:06 UTC
# 1         27835199  2009-07-17 20:04:56          7.7  2009-07-17 20:04:56 UTC
# 2         44984355  2009-08-24 21:45:00         12.9  2009-08-24 21:45:00 UTC
# 3         25894730   2009-06-26 8:22:21          5.3  2009-06-26 08:22:21 UTC
# 4         17610152  2014-08-28 17:47:00         16.0  2014-08-28 17:47:00 UTC
# ...            ...                  ...          ...                      ...
# 199995    42598914  2012-10-28 10:49:00          3.0  2012-10-28 10:49:00 UTC
# 199996    16382965   2014-03-14 1:09:00          7.5  2014-03-14 01:09:00 UTC
# 199997    27804658   2009-06-29 0:42:00         30.9  2009-06-29 00:42:00 UTC
# 199998    20259894  2015-05-20 14:56:25         14.5  2015-05-20 14:56:25 UTC
# 199999    11951496   2010-05-15 4:08:00         14.1  2010-05-15 04:08:00 UTC
#
# ...

# %%
conda install matplotlib
# Out:
# ...
# Solving environment: ...working... done
#
# # All requested packages already installed.
#
#
# Note: you may need to restart the kernel to use updated packages.
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.10.1
#   latest version: 23.5.2
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda

# %%
import matplotlib.pyplot as pp

# %%
c=b[['pickup_latitude','dropoff_latitude']]
c
# Out:
#      pickup_latitude  dropoff_latitude
# 0          40.738354         40.723217
# 1          40.728225         40.750325
# 2          40.740770         40.772647
# 3          40.790844         40.803349
# 4          40.744085         40.761247
# ..               ...               ...
# 995        40.757577         40.766960
# 996        40.757054         40.775632
# 997        40.765078         40.783833
# 998        40.784730         40.775048
# 999        40.729944         40.758208
#
# [1000 rows x 2 columns]

# %% [markdown]
# To print line chart

# %%
c.plot.line()
# Out:
# <AxesSubplot:>

# %% [markdown]
# To print bar chart()

# %%
c.plot.bar()
# Out:
# <AxesSubplot:>

# %% [markdown]
# To print area chart()

# %%
c.plot.area()
# Out:
# <AxesSubplot:>

# %% [markdown]
# To print box chart

# %%
c.plot.box()
# Out:
# <AxesSubplot:>

# %% [markdown]
# To print histogram

# %%
c.plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %% [markdown]
# To print scatter

# %%
c.plot.scatter(x='pickup_latitude',y='dropoff_latitude')
# Out:
# <AxesSubplot:xlabel='pickup_latitude', ylabel='dropoff_latitude'>

# %% [markdown]
# To print Pie chart

# %%
c.plot.pie(y='dropoff_latitude',figsize=(5,5))
# Out:
# <AxesSubplot:ylabel='dropoff_latitude'>
