# %%
import pandas as pd
import numpy as np

# %%
a=pd.read_csv(r"C:\Users\user\Downloads\fiat500_VehicleSelection_Dataset.csv")

# %% [markdown]
# To print 1st Five Rows

# %%
a.head(5)
# Out:
#     ID   model  engine_power  age_in_days        km  previous_owners  \
# 0  1.0  lounge          51.0        882.0   25000.0              1.0
# 1  2.0     pop          51.0       1186.0   32500.0              1.0
# 2  3.0   sport          74.0       4658.0  142228.0              1.0
# 3  4.0  lounge          51.0       2739.0  160000.0              1.0
# 4  5.0     pop          73.0       3074.0  106880.0              1.0
#
#          lat          lon price  Unnamed: 9 Unnamed: 10
# 0  44.907242  8.611559868  8900         NaN         NaN
# 1  45.666359  12.24188995  8800         NaN         NaN
# 2  45.503300     11.41784  4200         NaN         NaN
# 3  40.633171  17.63460922  6000         NaN         NaN
# 4  41.903221  12.49565029  5700         NaN         NaN

# %% [markdown]
# To print last 5 rows

# %%
a.tail()
# Out:
#       ID model  engine_power  age_in_days  km  previous_owners  lat  \
# 1544 NaN   NaN           NaN          NaN NaN              NaN  NaN
# 1545 NaN   NaN           NaN          NaN NaN              NaN  NaN
# 1546 NaN   NaN           NaN          NaN NaN              NaN  NaN
# 1547 NaN   NaN           NaN          NaN NaN              NaN  NaN
# 1548 NaN   NaN           NaN          NaN NaN              NaN  NaN
#
#               lon     price  Unnamed: 9 Unnamed: 10
# 1544       length         5         NaN         NaN
# 1545       concat  lonprice         NaN         NaN
# 1546  Null values        NO         NaN         NaN
# 1547         find         1         NaN         NaN
# 1548       search         1         NaN         NaN

# %% [markdown]
# To find shape

# %%
a.shape
# Out:
# (1549, 11)

# %% [markdown]
# To find size

# %%
a.size
# Out:
# 17039

# %% [markdown]
# To describe

# %%
a.describe()
# Out:
#                 ID  engine_power  age_in_days             km  previous_owners  \
# count  1538.000000   1538.000000  1538.000000    1538.000000      1538.000000
# mean    769.500000     51.904421  1650.980494   53396.011704         1.123537
# std     444.126671      3.988023  1289.522278   40046.830723         0.416423
# min       1.000000     51.000000   366.000000    1232.000000         1.000000
# 25%     385.250000     51.000000   670.000000   20006.250000         1.000000
# 50%     769.500000     51.000000  1035.000000   39031.000000         1.000000
# 75%    1153.750000     51.000000  2616.000000   79667.750000         1.000000
# max    1538.000000     77.000000  4658.000000  235000.000000         4.000000
#
#                lat  Unnamed: 9
# count  1538.000000         0.0
# mean     43.541361         NaN
# std       2.133518         NaN
# min      36.855839         NaN
# 25%      41.802990         NaN
# 50%      44.394096         NaN
# 75%      45.467960         NaN
# ...

# %% [markdown]
# To fill the null value

# %%
a.fillna(value=3)
# Out:
#        ID   model  engine_power  age_in_days        km  previous_owners  \
# 0     1.0  lounge          51.0        882.0   25000.0              1.0
# 1     2.0     pop          51.0       1186.0   32500.0              1.0
# 2     3.0   sport          74.0       4658.0  142228.0              1.0
# 3     4.0  lounge          51.0       2739.0  160000.0              1.0
# 4     5.0     pop          73.0       3074.0  106880.0              1.0
# ...   ...     ...           ...          ...       ...              ...
# 1544  3.0       3           3.0          3.0       3.0              3.0
# 1545  3.0       3           3.0          3.0       3.0              3.0
# 1546  3.0       3           3.0          3.0       3.0              3.0
# 1547  3.0       3           3.0          3.0       3.0              3.0
# 1548  3.0       3           3.0          3.0       3.0              3.0
#
#             lat          lon     price  Unnamed: 9 Unnamed: 10
# ...

# %% [markdown]
# To drop the null value rows

# %%
a.dropna()
# Out:
# Empty DataFrame
# Columns: [ID, model, engine_power, age_in_days, km, previous_owners, lat, lon, price, Unnamed: 9, Unnamed: 10]
# Index: []

# %% [markdown]
# To check the null values

# %%
a.isna()
# Out:
#          ID  model  engine_power  age_in_days     km  previous_owners    lat  \
# 0     False  False         False        False  False            False  False
# 1     False  False         False        False  False            False  False
# 2     False  False         False        False  False            False  False
# 3     False  False         False        False  False            False  False
# 4     False  False         False        False  False            False  False
# ...     ...    ...           ...          ...    ...              ...    ...
# 1544   True   True          True         True   True             True   True
# 1545   True   True          True         True   True             True   True
# 1546   True   True          True         True   True             True   True
# 1547   True   True          True         True   True             True   True
# 1548   True   True          True         True   True             True   True
#
#         lon  price  Unnamed: 9  Unnamed: 10
# ...

# %%
b=a[["age_in_days","km"]]
b
# Out:
#       age_in_days        km
# 0           882.0   25000.0
# 1          1186.0   32500.0
# 2          4658.0  142228.0
# 3          2739.0  160000.0
# 4          3074.0  106880.0
# ...           ...       ...
# 1544          NaN       NaN
# 1545          NaN       NaN
# 1546          NaN       NaN
# 1547          NaN       NaN
# 1548          NaN       NaN
#
# [1549 rows x 2 columns]

# %%
conda install matplotlib
# Out:
# ...
# Solving environment: ...working... done
#
# # All requested packages already installed.
#
#
# Note: you may need to restart the kernel to use updated packages.
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.10.1
#   latest version: 23.5.2
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda

# %%
import matplotlib.pyplot as pp

# %%
b.plot.line()
# Out:
# <AxesSubplot:>

# %%
b.plot.bar()
# Out:
# <AxesSubplot:>

# %%
b.plot.area()
# Out:
# <AxesSubplot:>

# %%
b.plot.box()
# Out:
# <AxesSubplot:>

# %%
b.plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
b.plot.pie(y='age_in_days',figsize=(5,5))
# Out:
# <AxesSubplot:ylabel='age_in_days'>

# %%
b.plot.scatter(x='age_in_days',y='km')
# Out:
# <AxesSubplot:xlabel='age_in_days', ylabel='km'>
